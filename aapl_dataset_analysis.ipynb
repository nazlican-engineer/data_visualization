# %%
# !pip install pandas data_reader
import pandas_datareader as pr
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.3/148.3 kB 2.0 MB/s eta 0:00:00
# ...

# %%
import yfinance as yf

df = yf.download("AAPL", start="2016-01-01", end="2019-08-25")
# Out:
# /tmp/ipython-input-2623422372.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("AAPL", start="2016-01-01", end="2019-08-25")
# [*********************100%***********************]  1 of 1 completed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 917 entries, 2016-01-04 to 2019-08-23
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   917 non-null    float64
#  1   (High, AAPL)    917 non-null    float64
#  2   (Low, AAPL)     917 non-null    float64
#  3   (Open, AAPL)    917 non-null    float64
#  4   (Volume, AAPL)  917 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 43.0 KB

# %% [markdown]
# **AAPLY VERİ SETİ**
#
# ✅Close:Gün sonundaki son fiyat
#
# ✅High:En yüksek fiyat
#
# ✅Low:En düşük fiyat
#
# ✅Open:Hisse senedinin açıldığı fiyat
#
# ✅Volume:toplam işlem sayısı

# %%
df.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2016-01-04  23.776176  23.780691  23.020124  23.157793  270597600
# 2016-01-05  23.180365  23.889023  23.112659  23.866455  223164000
# 2016-01-06  22.726728  23.103628  22.539409  22.695132  273829600
# 2016-01-07  21.767559  22.598089  21.763046  22.270843  324377600
# 2016-01-08  21.882656  22.367884  21.837519  22.241500  283192000

# %%
df.shape
# Out:
# (917, 5)

# %%
df.size
# Out:
# 4585

# %%
kapanis=df["Close"]

# %%
kapanis
# Out:
# Ticker           AAPL
# Date
# 2016-01-04  23.776176
# 2016-01-05  23.180365
# 2016-01-06  22.726728
# 2016-01-07  21.767559
# 2016-01-08  21.882656
# ...               ...
# 2019-08-19  50.650249
# 2019-08-20  50.652660
# 2019-08-21  51.201660
# 2019-08-22  51.158318
# 2019-08-23  48.793758
#
# [917 rows x 1 columns]

# %%
kapanis.plot();

# %%
#tarihler doğru şeklinde tanımlanması gerekiyor
#zaman değişkenin bir zaman değişkeni olduğu belirtilmeli
import pandas as pd
kapanis.index=pd.DatetimeIndex(kapanis.index)

# %%
kapanis.head()
# Out:
# Ticker           AAPL
# Date
# 2016-01-04  23.776176
# 2016-01-05  23.180365
# 2016-01-06  22.726728
# 2016-01-07  21.767559
# 2016-01-08  21.882656

# %%
kapanis.plot()
# Out:
# <Axes: xlabel='Date'>

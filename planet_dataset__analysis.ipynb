# %%
import seaborn as sns
planets=sns.load_dataset("planets")
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
#1.Soru:Veri setinin hikayesi nedir?
#Veri setinin  nasıl oluştuğunu anlamak
#Nasıl toplandı
df=planets.copy()

# %% [markdown]
# PLANETS VERİ SETİ
#
# ✅method:gezegenin keşif yöntemi
#
# ✅number:Gezegenin numarası
#
# ✅orbital_period:gezegenin galaksiye olan periyodu
#
# ✅mass:gezegenin kütlesi
#
# ✅distance:gezegenin galaksiye olan uzaklığı
#
# ✅year:gezegenin bulunduğu yılı

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1        3.941507   NaN     172.0  2006
# 1031  Transit       1        2.615864   NaN     148.0  2007
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
#Veri setinin yapısal  bilgilerine ulaş

# %%
df.info() #Dtype object olduğunda bu kategorik olduğunu gösteriyor
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df.dtypes
# Out:
# method             object
# number              int64
# orbital_period    float64
# mass              float64
# distance          float64
# year                int64
# dtype: object

# %%
df["method"].value_counts().count()#10 tane farklı değer var
# Out:
# np.int64(10)

# %%
import pandas as pd
df.method=pd.Categorical(df.method)#object türünü kategorik değişkene dönüştürmek için kullanılır

# %%
df.dtypes
# Out:
# method            category
# number               int64
# orbital_period     float64
# mass               float64
# distance           float64
# year                 int64
# dtype: object

# %%
df.describe(include="all").T #Tüm değişkenleri barındırır.Kategorik olanlar da dahil.
# Out:
#                  count unique              top freq         mean  \
# method            1035     10  Radial Velocity  553          NaN
# number          1035.0    NaN              NaN  NaN     1.785507
# orbital_period   992.0    NaN              NaN  NaN  2002.917596
# mass             513.0    NaN              NaN  NaN     2.638161
# distance         808.0    NaN              NaN  NaN   264.069282
# year            1035.0    NaN              NaN  NaN  2009.070531
#
#                          std       min      25%      50%      75%       max
# method                   NaN       NaN      NaN      NaN      NaN       NaN
# number              1.240976       1.0      1.0      1.0      2.0       7.0
# orbital_period  26014.728304  0.090706  5.44254  39.9795  526.005  730000.0
# mass                3.818617    0.0036    0.229     1.26     3.04      25.0
# distance          733.116493      1.35    32.56    55.25    178.5    8500.0
# ...

# %%
df.shape
# Out:
# (1035, 6)

# %%
#eksik değerler
df.isnull().count()
'''
isnull:her hücrenin boş veya dolu olup olmadığını gösteriyor
count:Aslında nan olmayan değerleri gösteriyor
fakat burada isnull sayesinde heer satur true veya false olarak doldurulduğu için count toplam satır sayısını getirir.
'''
# Out:
# '\nisnull:her hücrenin boş veya dolu olup olmadığını gösteriyor\ncount:Aslında nan olmayan değerleri gösteriyor\nfakat burada isnull sayesinde heer satur true veya false olarak doldurulduğu için count toplam satır sayısını getirir.\n'

# %%
df.isnull().values.any()
# Out:
# np.True_

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df["orbital_period"].fillna(0,inplace=True)
# Out:
# /tmp/ipython-input-2034127425.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["orbital_period"].fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period      0
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df["distance"].fillna(df["distance"].mean,inplace=True)
# Out:
# /tmp/ipython-input-1134303824.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<bound method Series.mean of 0        77.40
# 1        56.95
# 2        19.84
# 3       110.62
# 4       119.47
#          ...
# 1030    172.00
# 1031    148.00
# 1032    174.00
# 1033    293.00
# 1034    260.00
# Name: distance, Length: 1035, dtype: float64>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df["distance"].fillna(df["distance"].mean,inplace=True)

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period      0
# mass              522
# distance            0
# year                0
# dtype: int64

# %%
df=planets.copy()

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
kat_df=df.select_dtypes(include = ["object"])

# %%
kat_df.head()
# Out:
#             method
# 0  Radial Velocity
# 1  Radial Velocity
# 2  Radial Velocity
# 3  Radial Velocity
# 4  Radial Velocity

# %%
kat_df.groupby("method").value_counts()
# Out:
# method
# Astrometry                         2
# Eclipse Timing Variations          9
# Imaging                           38
# Microlensing                      23
# Orbital Brightness Modulation      3
# Pulsar Timing                      5
# Pulsation Timing Variations        1
# Radial Velocity                  553
# Transit                          397
# Transit Timing Variations          4
# Name: count, dtype: int64

# %%
kat_df["method"].value_counts()
# Out:
# method
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: count, dtype: int64

# %%
kat_df["method"].value_counts().plot.barh();#Sütun grafikler veri setindeki kategorik değişlenleri göstermek için kullanılır.

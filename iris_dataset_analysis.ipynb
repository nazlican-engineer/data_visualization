# %%
import seaborn as sns
iris=sns.load_dataset("iris")
df=iris.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# **İRİS VERİ SETİ:**
#
# ✅sepal_length:çanak yaprağın uzunluğu
#
# ✅sepal_width:çanak yaprağın genişliği
#
# ✅petal_length:taç yaprağın uzunluğu
#
# ✅petal_widthtaç yaprağın genişliği
#
# ✅species:çiçeğin türü

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#species nominal tüpte veri olduğu için object türünde kalabilir
'''
SORU:peki neden ordinal tipte olduğu zaman object türünde bırakmıyoruz da categori tipine çevirmemiz lazım?
CEVAP:Bu soruyu şöyle açıklamak gerekirse ordinal tipte olduğu zaman onu object türünde bıraktığımız zaman pandas bunun bir kategori tipte olduğunu anlamaz
yani düşük-orta-yüksek olduğunu anlamaz.
'''
# Out:
# '\nSORU:peki neden ordinal tipte olduğu zaman object türünde bırakmıyoruz da categori tipine çevirmemiz lazım?\nCEVAP:Bu soruyu şöyle açıklamak gerekirse ordinal tipte olduğu zaman onu object türünde bıraktığımız zaman pandas bunun bir kategori tipte olduğunu anlamaz\nyani düşük-orta-yüksek olduğunu anlamaz.\n'

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.size
# Out:
# 750

# %%
sns.pairplot(df)#bir veri seti içindeki değişkenlerin herbirinin kendi aralarındaki ilişkilere bakıyor
'''
GRAFİKLER:Veri setin içindeki dağılımı gösteriyor
Scatterplot görsellerinde oluşturulmuş olan grafik bir toz bulutu şeklindeyse veya yapısal bir formu yoksa o iki değişken arasında bir ilişki olmadığını gösterir
Gözlem noktaları birbirnden farklı köşelerde kümeleniyorsa bu durumda çaprazlama durumları ile anlayabileceğimiz bu kümeleri oluşturan farklı farklı alt kümeler vardır
burada sütun grafiklerinde x ve y  eksenlerinde aynı değerler var burada pairplot nokta şeklinde gösteremez iki eksen de aynı olduğu için birbirlerinin üstüne binerdi
bu yüzden pairplot sütun grafikleriyle gösteriyor bu grafikleri
'''
# Out:
# '\nGRAFİKLER:Veri setin içindeki dağılımı gösteriyor\nScatterplot görsellerinde oluşturulmuş olan grafik bir toz bulutu şeklindeyse veya yapısal bir formu yoksa o iki değişken arasında bir ilişki olmadığını gösterir\nGözlem noktaları birbirnden farklı köşelerde kümeleniyorsa bu durumda çaprazlama durumları ile anlayabileceğimiz bu kümeleri oluşturan farklı farklı alt kümeler vardır\n'

# %%
sns.pairplot(df,hue="species")

# %%
sns.pairplot(df,hue="species",markers=["o","s","d"])

# %%
sns.pairplot(df,hue="species",kind="reg")
